# %% [markdown]
# ## Все данные будем извлекать с двух ресурсов: [fanfics.me](fanfics.me) и [ficbook.ru](ficbook.ru)

# %% [markdown]
# Какие вообще данные в теории понадобятся?
# - название
# - ссылка
# - описание фанфика
# - персонажи
# - пейринги
# - фандомы
# - возрастной рейтинг
# - теги отношений (слеш/джен/гет/фем)
# - тег размера (мини/миди/макси/драббл)
# - размер
# - статус
# - события (можно получить только для фанфиков с [fanfics.me](fanfics.me))
# - жанры
# - предупреждения

# %% [markdown]
# ## Что вообще происходит?

# %% [markdown]
# Сейчас мы будем доставать все вышеописанные данные с сайта. Для этого нужно открыть страницу со списком фанфиков и достать оттуда все названия, описания, персонажей и так далее. Чтобы произвести эти действия, нужно использовать специализированные библиотеки.

# %%
import requests # библиотека для доступа к исходному коду страниц
from bs4 import BeautifulSoup # библиотека для «вытаскивания» нужных нам данных из исходного кода страницы

# %% [markdown]
# Каждая страница с фанфикам по Гарри Поттеру на [fanfics.me](fanfics.me) выглядит следующим образом:
# >https://fanfics.me/find?fandom1=2&page=1
#
# где последнее число отвечает за номер страницы. Всего таких страниц с фанфиками 1031 на момент написания этого кода. Давайте вытащим исходный код каждой страницы в цикле.

# %%
URLs = ['https://fanfics.me/find?fandom1=2&page=' + str(page) for page in range(1, 3)]
page_sources = [requests.get(url) for url in URLs]

# %% [markdown]
# Исходный код надо превратить в «суп», с которым будем удобно работать для поиска информации на странице. «Суп» будем искать для каждой страницы, исходный код которой мы получили. Тем самым получим список с «супами».

# %%
soups = [BeautifulSoup(page_source.content, 'html.parser') for page_source in page_sources]

# %% [markdown]
# Вся информация о фанфике содержится в контейнере
# ```html
# <table class='FicTbl'>
# ```
# Поэтому для каждого «супа» найдём все разделы с информацией о фанфиках, тем самым мы получим «суп» для каждого фанфика.

# %%
fanfic_soups = []
for soup in soups:
    fanfic_soups += soup.find_all('table', class_='FicTbl')

# %% [markdown]
# ## Названия
# Если внимательно посмотреть на код страницы, то становится ясно, что интересующее нас название лежит в контейнере
# ```html
# <div class='FicTable_Title'>
# ```
# так что ищем этот контейнер (он всего один для каждого «супа», поэтому используем `find` вместо `find_all`)

# %%
title_meta = [soup.find('div', class_='FicTable_Title') for soup in fanfic_soups]
title_meta[0]
# Out:
# <div class="FicTable_Title">
# <h4><a href="/fic100769">Невилл и все, все, все</a> <span class="small gen">(джен)</span></h4>
# <div class="FicTable_Stat"><span class="Views" style="margin-right:20px;" title="Количество просмотров 153 305">153k</span>
# <span class="ReadersCount" style="margin-right:20px;" title="Количество читателей 1 023">1k</span><span class="Comments" style="margin-right:20px;" title="Количество комментариев 236">236</span><span class="RecommendsCount" style="margin-right:20px;" title="Количество рекомендаций">4</span><span class="DateUpdate" style="margin-right:20px;" title="Опубликовано 21.01.2017, изменено 08.02.2021">08.02.2021</span></div>
# </div>

# %% [markdown]
# Проблема в том, что контейнер содержит не только название, но и ещё массу лишней информации, поэтому находим уникальный для названия контейнер -- это контейнер `<a>`, он применяется только к названию.

# %%
titles = [soup.find('a').text for soup in title_meta]
titles[0]
# Out:
# 'Невилл и все, все, все'

# %% [markdown]
# ## Ссылка

# %%
links = ['fanfics.me' + soup.find('a')['href'] for soup in title_meta]
links[0]
# Out:
# 'fanfics.me/fic100769'

# %% [markdown]
# ## Описания
# Описание лежит в контейнере
# ```html
# <td class='FicTbl_sammary'>
# ```
# так что ищем этот контейнер (он всего один для каждого «супа», поэтому используем `find` вместо `find_all`)

# %%
summaries = [soup.find('td', class_='FicTbl_sammary').text for soup in fanfic_soups]
summaries[0]
# Out:
# 'Когда Невиллу дядя подарил жабу, началась цепь событий, встряхнувших  и изменивших магический мир.'

# %% [markdown]
# ## Персонажи

# %%
import re

# %%
characters = []
for soup in fanfic_soups:
    single = [char.text for char in soup.find_all(href=re.compile('/character.*'))]
    pairings = [pair.text.split('/') for pair in soup.find_all(href=re.compile('/paring.*'))]
    for pairing in pairings:
        single += pairing
    single = list(set(single))
    characters.append(', '.join(single))
characters[0]
# Out:
# 'Кащей Бессмертный, Беллатриса Лестрейндж, Драко Малфой, Невилл Лонгботтом, Гарри Поттер, Люциус Малфой, Родольфус Лестрейндж, Новый Женский Персонаж, Царевна-лягушка, Нарцисса Малфой, Августа Лонгботтом, Северус Снейп'

# %% [markdown]
# ## Пейринги

# %%
pairings = []
for soup in fanfic_soups:
    fic_pairings = [pair.text for pair in soup.find_all(href=re.compile('/paring.*'))]
    pairings.append(', '.join(fic_pairings))
pairings[0]
# Out:
# 'Беллатриса Лестрейндж/Родольфус Лестрейндж, Люциус Малфой/Нарцисса Малфой'

# %% [markdown]
# ## Фандомы

# %%
fandoms = []
for soup in fanfic_soups:
    fic_fandoms = [fandom.text for fandom in soup.find_all(href=re.compile('/fandom.*'))]
    fandoms.append(', '.join(fic_fandoms))
fandoms[0]
# Out:
# 'Гарри Поттер, Русские народные сказки'

# %% [markdown]
# ## Возрастной рейтинг

# %%
ratings = [soup.find('span', class_='FicTable_Rating').text for soup in fanfic_soups]
ratings[0]
# Out:
# 'General'

# %% [markdown]
# ## Теги отношений

# %%
relationships = [soup.find('div', class_='FicTable_Title').find('h4').find('span').text.strip('()') for soup in fanfic_soups]
relationships[0]
# Out:
# 'джен'

# %% [markdown]
# ## Теги размера + размер

# %%
sizes_full = [soup.find('span', class_='FicTable_Size').text.split('|') for soup in fanfic_soups]
size_tags = [size_full[0].strip() for size_full in sizes_full]
sizes = [size_full[1].strip()[:-3] for size_full in sizes_full]
(size_tags[0], sizes[0])
# Out:
# ('Макси', '2164')

# %% [markdown]
# ## Статус

# %%
statuses = [soup.find('span', class_='FicTable_Status').text.replace('\xa0', ' ') for soup in fanfic_soups]
statuses[0]
# Out:
# 'В процессе'

# %% [markdown]
# ## События

# %%
events = []
for soup in fanfic_soups:
    fic_events = [event.text for event in soup.find_all(href=re.compile('/find\?keyword=.*'))]
    events.append(', '.join(fic_events))
events[0]
# Out:
# 'Детство героев, Том Риддл - человек, Много оригинальных героев, Путешествие во времени, Экзотическое место действия, Адекватные Дурсли, Тайный план Дамблдора'

# %% [markdown]
# ## Жанры

# %%
meta_unfiltered = [soup.find('td', class_='FicTbl_meta').text for soup in fanfic_soups]
meta_unfiltered[0]
# Out:
# '\nАвторы:\xa0б-кап, Adelaidetweetie\n\nФандомы:\xa0Гарри Поттер, Русские народные сказки\n\nПерсонажи:\xa0Невилл Лонгботтом, Августа Лонгботтом, Гарри Поттер, Царевна-лягушка, Кащей Бессмертный, Беллатриса Лестрейндж/Родольфус Лестрейндж, Драко Малфой, Новый Женский Персонаж, Люциус Малфой/Нарцисса Малфой, Северус Снейп\nРейтинг:\xa0General\n\nЖанры:\xa0Сказка, Кроссовер\n                    \nРазмер:\xa0Макси | 2164 Кб\n\nСтатус:\xa0В\xa0процессе\nПредупреждения:\xa0AU, ООС\n                    События:\xa0Детство героев, Том Риддл - человек, Много оригинальных героев, Путешествие во времени, Экзотическое место действия, Адекватные Дурсли, Тайный план Дамблдора\n3\n'

# %%
genres_regex = re.compile('Жанры:\\xa0(.*)\\n +')

# %%
genres = []
for meta in meta_unfiltered:
    match = re.search(genres_regex, meta)
    if match:
        genres.append(match.group(1))
    else:
        genres.append('')
genres[0]
# Out:
# 'Сказка, Кроссовер'

# %% [markdown]
# ## Предупреждения

# %%
warnings_regex = re.compile('Предупреждения:\\xa0(.*)\\n +')

# %%
warnings = []
for meta in meta_unfiltered:
    match = re.search(warnings_regex, meta)
    if match:
        warnings.append(match.group(1))
    else:
        warnings.append('')
warnings[0]
# Out:
# 'AU, ООС'

# %% [markdown]
# ## Делаем pandas датафрейм!

# %%
data = {
    'title': titles,
    'summary': summaries,
    'characters': characters,
    'pairings': pairings,
    'fandoms': fandoms,
    'rating': ratings,
    'size_tag': size_tags,
    'size': sizes,
    'statuse': statuses,
    'events': events,
    'genres': genres,
    'warnings': warnings,
    'link': links
}

# %%
import pandas as pd
fanfictionDF = pd.DataFrame(data, columns = data.keys())
fanfictionDF
# Out:
#                                                 title  \
# 0                              Невилл и все, все, все
# 1   Укрощение строптивых (Хорошее дело браком не н...
# 2                                       Истина во сне
# 3                                           Только ты
# 4                                       Другие берега
# 5                Панси Паркинсон и ее волшебные твари
# 6                   Последняя из Слизеринов. Книга IV
# 7      Большая Игра профессора Дамблдора. Продолжение
# 8                                  Беглец из прошлого
# 9                                          Игра теней
# 10                                Тайны Тёмного Лорда
# 11                                       Как все было
# 12                                  47 days to change
# 13                                              Изгои
# 14         Хранитель магии II: тайна чёрной шкатулки.
# 15                             Спас? А теперь – беги!
# 16                                          Наследник
# 17                                     Старушка Петти
# 18                                   Шестьдесят минут
# 19                                  О чём шепчет тьма
# 20                     Гарри Поттер и Хранитель магии
# 21                           Сакральная собственность
# 22                                   Взгляд Майкрофта
# 23                                        Острые углы
# 24  Ничего на свете лучше нету, чем явиться в сред...
# 25                                        Кровные узы
# 26                       Фините Инкантатем не поможет
# 27                                  Руками не трогать
# 28                                  Пиши мне, хорошо?
# 29                                      Разгляди меня
# 30     Чего не хватает миру ГП? Правильно, психолога!
# 31                        Мы же все сделали правильно
# 32                                    British Warlock
# 33                                Прожить чужую жизнь
# 34                                       Сонное зелье
# 35                   Усы? Лапы? И, главное... Хвост?!
# 36                              Digging for the Bones
# 37                                      Зелёное Пламя
# 38                     Последняя надежда человечества
# 39                          Пятьдесят оттенков серого
#
#                                               summary  \
# 0   Когда Невиллу дядя подарил жабу, началась цепь...
# 1   Часть 2 "Хорошее дело браком не назовут". \nТа...
# 2   «И часто ты бываешь в моих снах, Гарри? Я не к...
# 3   Гермиона даже в самые тяжелые годы считала, чт...
# 4   А, что если Гарри по-настоящему любил только Г...
# 5   Панси Паркинсон в поиске. А кто ищет, тот найдет.
# 6   Пятый курс остался за плечами, расставив некот...
# 7   Многие знают о существовании Большой Игры – те...
# 8   Северус Снейп и Дилан Бэрк, волею судьбы попав...
# 9   Великий маг играет людьми ради Всеобщего Блага...
# 10  Оборотная сторона луны - события саги о Гарри ...
# 11  Планируется рассказ о жизни Снейпа. От дошколь...
# 12  Гарри Поттер и Том Риддл — предреченные символ...
# 13  ...Магии они лишились все – все, кто согласилс...
# 14  —Не стоит меня сравнивать с отцом, мистер Потт...
# 15  Что может быть страшнее, чем умереть от руки л...
# 16  Гермиона пропадает во время битвы за Хогвартс....
# 17  Однажды Петунья Дурсль услышала то, что ей не ...
# 18  Шестьдесят минут из жизни трех человек и многи...
# 19  На сколько же плоха тьма, и так ли добр свет. ...
# 20  — Теперь ты не можешь причинить вреда Гарри По...
# 21  В Лондоне процветает работорговля среди состоя...
# 22  На политической арене Великобритании выступает...
# 23  У острых углов есть последствия, но Северусу С...
# 24  Случайности не случайны. Знакомая фраза? Гарри...
# 25  Они молоды и импульсивны, слишком упрямы и гор...
# 26  Гарри всего лишь хотел спокойно подготовиться ...
# 27  Длинная история о чрезвычайно забитом Гарри По...
# 28  Драко Малфой уезжает учиться в волшебную школу...
# 29  Седрику и Гарри невероятно повезло уйти живыми...
# 30  История о попаданке в мир Гарри Поттера. Учась...
# 31  История о том как Снейп зависит от Поттера. Ил...
# 32  Говорят, что нужный человек не в то время и не...
# 33  Очутиться в другом мире, прожить чужую жизнь д...
# 34  На протяжении шести лет профессора Снейпа по н...
# 35  Начинается история тем, что Гарри в возрасте в...
# 36  После скандала с тётушкой Мардж Гарри сбежал и...
# 37  «Ты — две стороны одной медали. На одной сторо...
# 38  После техногенной катастрофы человечество стои...
# 39  Студенту Драко Малфою по нелепой случайности п...
#
#                                            characters  \
# 0   Кащей Бессмертный, Беллатриса Лестрейндж, Драк...
# 1   Беллатриса Лестрейндж, Рабастан Лестрейндж, Ло...
# 2            Гарри Поттер, Лорд Волдеморт (Том Риддл)
# 3   Джинни Уизли, Рон Уизли, Гарри Поттер, Гермион...
# 4   Рон Уизли, Гарри Поттер, Изабелла Свон (Белла)...
# 5   Драко Малфой, Дадли Дурсль, Симус Финниган, Па...
# 6   Драко Малфой, Гарри Поттер, Новый Мужской Перс...
# 7        Северус Снейп, Гарри Поттер, Альбус Дамблдор
# 8   Северус Снейп, Гарри Поттер, Альбус Дамблдор, ...
# 9                    Гермиона Грейнджер, Гарри Поттер
# 10  Беллатриса Лестрейндж, Люциус Малфой, Гарри По...
# 11  Эйлин Принц, Эйвери, Альбус Дамблдор, Ремус Лю...
# 12  Беллатриса Лестрейндж, Рон Уизли, Гарри Поттер...
# 13  Новый Мужской Персонаж, Рабастан Лестрейндж, Н...
# 14  Рон Уизли, Гарри Поттер, Новый Мужской Персона...
# 15           Северус Снейп, Гарри Поттер, Виктор Крам
# 16                  Гермиона Грейнджер, Люциус Малфой
# 17  Северус Снейп, Гарри Поттер, Дадли Дурсль, Пет...
# 18  Альбус Северус Поттер, Скорпиус Малфой, Хьюго ...
# 19  Драко Малфой, Невилл Лонгботтом, Панси Паркинс...
# 20  Астория Гринграсс, Драко Малфой, Рон Уизли, Лю...
# 21         Вернон Дурсль, Гарри Поттер, Северус Снейп
# 22                 Гермиона Грейнджер, Майкрофт Холмс
# 23  Нимфадора Тонкс, Люциус Малфой, Гарри Поттер, ...
# 24  Майкл Корнер, Драко Малфой, Невилл Лонгботтом,...
# 25  Альбус Северус Поттер, Роза Уизли, Новый Мужск...
# 26  Драко Малфой, Джинни Уизли, Рон Уизли, Гарри П...
# 27  Чо Чанг, Джинни Уизли, Фред Уизли, Антонин Дол...
# 28  Драко Малфой, Рон Уизли, Гарри Поттер, Панси П...
# 29         Седрик Диггори, Гарри Поттер, Драко Малфой
# 30  Драко Малфой, Невилл Лонгботтом, Джинни Уизли,...
# 31  Драко Малфой, Невилл Лонгботтом, Гарри Поттер,...
# 32  Драко Малфой, Панси Паркинсон, Гарри Поттер, Л...
# 33  Дадли Дурсль, Невилл Лонгботтом, Гарри Поттер,...
# 34                        Северус Снейп, Гарри Поттер
# 35  Гермиона Грейнджер, Гарри Поттер, Невилл Лонгб...
# 36  Гарри Поттер, Гермиона Грейнджер, Альбус Дамбл...
# 37  Драко Малфой, Фред Уизли, Гарри Поттер, Рон Уи...
# 38  Астория Гринграсс, Драко Малфой, Рон Уизли, Га...
# 39                         Гарри Поттер, Драко Малфой
#
#                                              pairings  \
# 0   Беллатриса Лестрейндж/Родольфус Лестрейндж, Лю...
# 1                 Беллатриса Лестрейндж/Северус Снейп
# 2             Гарри Поттер/Лорд Волдеморт (Том Риддл)
# 3   Гермиона Грейнджер/Северус Снейп, Гермиона Гре...
# 4   Гарри Поттер/Гермиона Грейнджер, Изабелла Свон...
# 5   Панси Паркинсон/Симус Финниган, Гарри Поттер/П...
# 6   Драко Малфой/Новый Женский Персонаж, Новый Жен...
# 7
# 8                Северус Снейп/Новый Мужской Персонаж
# 9                     Гарри Поттер/Гермиона Грейнджер
# 10  Беллатриса Лестрейндж/Лорд Волдеморт (Том Ридд...
# 11
# 12            Лорд Волдеморт (Том Риддл)/Гарри Поттер
# 13
# 14
# 15  Гарри Поттер/Северус Снейп, Гарри Поттер/Викто...
# 16                   Гермиона Грейнджер/Люциус Малфой
# 17
# 18  Альбус Северус Поттер/Скорпиус Малфой, Роза Уи...
# 19                  Невилл Лонгботтом/Панси Паркинсон
# 20  Люциус Малфой/Нарцисса Малфой/Родольфус Лестре...
# 21                         Гарри Поттер/Северус Снейп
# 22                  Майкрофт Холмс/Гермиона Грейнджер
# 23  Северус Снейп/Сириус Блэк, Северус Снейп/Новый...
# 24  Северус Снейп/Джемма Фарли, Гарри Поттер/Джинн...
# 25  Джеймс Поттер-младший/Новый Женский Персонаж, ...
# 26  Гарри Поттер/Драко Малфой, Гермиона Грейнджер/...
# 27  Гарри Поттер/Нимфадора Тонкс, Гарри Поттер/Чо ...
# 28                          Гарри Поттер/Драко Малфой
# 29           Гарри Поттер/Драко Малфой/Седрик Диггори
# 30                    Гарри Поттер/Гермиона Грейнджер
# 31  Гарри Поттер/Северус Снейп, Драко Малфой/Невил...
# 32
# 33                    Гарри Поттер/Гермиона Грейнджер
# 34                         Гарри Поттер/Северус Снейп
# 35                    Гарри Поттер/Гермиона Грейнджер
# 36
# 37
# 38  Гарри Поттер/Северус Снейп, Гермиона Грейнджер...
# 39                          Гарри Поттер/Драко Малфой
#
#                                   fandoms   rating size_tag  size     statuse  \
# 0   Гарри Поттер, Русские народные сказки  General    Макси  2164  В процессе
# 1                            Гарри Поттер        R     Миди    22  В процессе
# 2                            Гарри Поттер    NC-17    Макси   263  В процессе
# 3                            Гарри Поттер    NC-17    Макси   536  В процессе
# 4                   Гарри Поттер, Сумерки    PG-13    Макси   210  В процессе
# 5                            Гарри Поттер    PG-13     Мини    10    Закончен
# 6                            Гарри Поттер    NC-17    Макси  1033  В процессе
# 7                            Гарри Поттер  General    Макси  2240  В процессе
# 8                            Гарри Поттер        R    Макси   227  В процессе
# 9                                                R     Мини    23    Закончен
# 10                           Гарри Поттер    PG-13    Макси   339  В процессе
# 11                           Гарри Поттер    PG-13    Макси   783  В процессе
# 12                           Гарри Поттер    NC-17    Макси  1114    Закончен
# 13                           Гарри Поттер        R    Макси  2731  В процессе
# 14                           Гарри Поттер    NC-17    Макси   766  В процессе
# 15                           Гарри Поттер    NC-17    Макси   819    Закончен
# 16                           Гарри Поттер        R     Мини    33    Закончен
# 17                           Гарри Поттер    PG-13    Макси   746  В процессе
# 18                           Гарри Поттер        R    Макси   264  В процессе
# 19                           Гарри Поттер        R    Макси   168  В процессе
# 20                           Гарри Поттер        R    Макси  3640  В процессе
# 21                           Гарри Поттер        R     Миди    19  В процессе
# 22               Шерлок BBC, Гарри Поттер        R    Макси   434  В процессе
# 23                           Гарри Поттер    NC-17     Миди    93  В процессе
# 24                           Гарри Поттер  General    Макси  1408  В процессе
# 25                           Гарри Поттер        R    Макси   199  В процессе
# 26                           Гарри Поттер    PG-13     Миди    55  В процессе
# 27                           Гарри Поттер    NC-17    Макси  1680  В процессе
# 28                           Гарри Поттер    NC-17    Макси    71  В процессе
# 29                           Гарри Поттер    PG-13    Макси    97  В процессе
# 30                           Гарри Поттер        R    Макси   988  В процессе
# 31                           Гарри Поттер    NC-17     Миди   178    Закончен
# 32                           Гарри Поттер    NC-17    Макси   896  В процессе
# 33                           Гарри Поттер        R    Макси   407  В процессе
# 34                           Гарри Поттер    NC-17    Макси   318  В процессе
# 35                           Гарри Поттер    PG-13     Миди   229  В процессе
# 36                           Гарри Поттер    PG-13    Макси   558  В процессе
# 37                                           NC-17    Макси   260  В процессе
# 38                           Гарри Поттер    NC-17    Макси   481  В процессе
# 39                           Гарри Поттер    NC-17    Макси   137  В процессе
#
#                                                events  \
# 0   Детство героев, Том Риддл - человек, Много ори...
# 1            Аристократия, Первая война с Волдемортом
# 2                                         Шестой курс
# 3   ПостХогвартс, Жизнь среди маглов, Волдеморт по...
# 4
# 5                                        ПостХогвартс
# 6   Шестой курс, Вторая война с Волдемортом, Дамби...
# 7
# 8   Четвертый курс, Чужая душа в теле героя Поттер...
# 9
# 10  Вторая война с Волдемортом, Первая война с Вол...
# 11  Детство героев, Времена Мародеров, Темная стор...
# 12               ПостХогвартс, Путешествие во времени
# 13  Исчезновение магических способностей, Волдемор...
# 14
# 15  Волдеморт побежден, ПостХогвартс, Сильный Гарр...
# 16
# 17  Дурсли - волшебники, Распределение в другие фа...
# 18  ГП и проклятое дитя, Дети главных героев, Любо...
# 19  Дамбигад, Распределение в другие факультеты, З...
# 20  Власти магического мира, Аристократия, Нестанд...
# 21                                    Немагическое AU
# 22                            Власти магического мира
# 23  Экзотическое место действия, Летом, Жизнь сред...
# 24                                       ПостХогвартс
# 25                                Дети главных героев
# 26  Волдеморт побежден, Восьмой курс, Квиддич, Рас...
# 27  Детство героев, Измененное пророчество, Квидди...
# 28  Детство героев, Распределение в другие факультеты
# 29
# 30                 Чужая душа в теле героя Поттерианы
# 31  ПостХогвартс, Седьмой курс, БДСМ, пытки, прину...
# 32  Пятый курс, Темная сторона, Вторая война с Вол...
# 33  Адекватные Дурсли, Дурсли - волшебники, Тайный...
# 34
# 35           Анимагия, Детство героев, Не в Хогвартсе
# 36                    Третий курс, Снейп - отец Гарри
# 37  Распределение в другие факультеты, Независимый...
# 38  Волдеморт побежден, Не в Хогвартсе, Колдомедиц...
# 39                                    Немагическое AU
#
#                                                genres  \
# 0                                   Сказка, Кроссовер
# 1                         Экшен, Юмор, Первый раз, AU
# 2                 Ангст, Даркфик, Hurt/comfort, Драма
# 3                                               Драма
# 4          Фэнтези, Кроссовер, Приключения, Романтика
# 5                                           Романтика
# 6                                             Даркфик
# 7                                              Статья
# 8                          Попаданцы, Приключения, AU
# 9                                           Романтика
# 10                                     Драма, Фэнтези
# 11                                       Драма, Общий
# 12                          Даркфик, Ужасы, Романтика
# 13                                              Драма
# 14                    Драма, Мистика, Детектив, Экшен
# 15             Даркфик, Ангст, Детектив, Hurt/comfort
# 16                                   Ангст, Драма, AU
# 17                                        Приключения
# 18                                       Драма, Ангст
# 19                              Фэнтези, Hurt/comfort
# 20              Первый раз, Драма, Приключения, Экшен
# 21                                       Hurt/comfort
# 22                                   Кроссовер, Общий
# 23                             Приключения, Романтика
# 24                Общий, Приключения, Романтика, Юмор
# 25            Романтика, Фэнтези, Драма, Hurt/comfort
# 26                            Романтика, Hurt/comfort
# 27  Первый раз, Романтика, Ангст, Юмор, Драма, Фэн...
# 28              Ангст, Драма, Романтика, Hurt/comfort
# 29                   Ангст, Драма, Романтика, Фэнтези
# 30         Романтика, Попаданцы, Приключения, Фэнтези
# 31                                                PWP
# 32                           Триллер, Детектив, Драма
# 33                       Попаданцы, Юмор, Приключения
# 34                Романтика, Ангст, Драма, Первый раз
# 35                Юмор, AU, Приключения, Hurt/comfort
# 36                       Ангст, Даркфик, Hurt/comfort
# 37                             Драма, Приключения, AU
# 38             Ангст, Даркфик, Драма, Постапокалипсис
# 39                       Драма, Первый раз, Романтика
#
#                                              warnings                  link
# 0                                             AU, ООС  fanfics.me/fic100769
# 1   AU, Насилие, Нецензурная лексика, Чёрный юмор,...  fanfics.me/fic159169
# 2                                         AU, Насилие  fanfics.me/fic157201
# 3                                            UST, ООС  fanfics.me/fic140892
# 4                                             AU, Гет   fanfics.me/fic71494
# 5                            Нецензурная лексика, ООС  fanfics.me/fic159266
# 6       AU, Гет, Мэри Сью, ООС, От первого лица (POV)  fanfics.me/fic150110
# 7                                                      fanfics.me/fic140884
# 8                        ООС, AU, Нецензурная лексика  fanfics.me/fic157064
# 9                                                       fanfics.me/fic54048
# 10                              Смерть персонажа, ООС  fanfics.me/fic157535
# 11                                                     fanfics.me/fic144053
# 12           Сомнительное согласие, AU, Слэш, Насилие  fanfics.me/fic115075
# 13                              Гет, Смерть персонажа  fanfics.me/fic146704
# 14                                                     fanfics.me/fic139087
# 15                 AU, ООС, Слэш, UST, Пытки, Насилие  fanfics.me/fic131714
# 16                                                ООС  fanfics.me/fic159254
# 17                                                 AU  fanfics.me/fic106955
# 18                    Гет, UST, Сомнительное согласие  fanfics.me/fic158711
# 19            Гет, Насилие, ООС, Смерть персонажа, AU  fanfics.me/fic152618
# 20        Инцест, AU, ООС, Гет, Смерть персонажа, UST  fanfics.me/fic148893
# 21                                        AU, Насилие  fanfics.me/fic156445
# 22                                                     fanfics.me/fic121511
# 23                  AU, Гет, Нецензурная лексика, ООС  fanfics.me/fic151394
# 24                                                ООС  fanfics.me/fic138768
# 25          AU, Нецензурная лексика, Смерть персонажа  fanfics.me/fic158257
# 26                                           UST, Гет  fanfics.me/fic159047
# 27         ООС, Насилие, Пытки, Смерть персонажа, Гет  fanfics.me/fic143597
# 28                                Нецензурная лексика  fanfics.me/fic159183
# 29                                                ООС  fanfics.me/fic158488
# 30                     Гет, От первого лица (POV), AU  fanfics.me/fic133469
# 31            Принуждение к сексу, Насилие, Гет, БДСМ  fanfics.me/fic158585
# 32            ООС, AU, Гет, Насилие, Смерть персонажа  fanfics.me/fic140127
# 33                     AU, ООС, От первого лица (POV)  fanfics.me/fic150677
# 34                                                UST  fanfics.me/fic147165
# 35                                                ООС  fanfics.me/fic157955
# 36                 AU, ООС, Насилие, Смерть персонажа  fanfics.me/fic155060
# 37          Насилие, Смерть персонажа, ООС, Слэш, Гет   fanfics.me/fic57812
# 38  AU, Гет, Изнасилование, Мужская беременность, ...  fanfics.me/fic139386
# 39                                          БДСМ, ООС  fanfics.me/fic158051

# %% [markdown]
# ## Пришло время сделать одну большую функцию для всего этого непотребства

# %%
genres_regex = re.compile('Жанры:\\xa0(.*)\\n +')
warnings_regex = re.compile('Предупреждения:\\xa0(.*)\\n +')

def processPage(url):
    page_source = requests.get(url)
    soup = BeautifulSoup(page_source.content, 'html.parser')
    fanfic_soups = soup.find_all('table', class_='FicTbl')
    
    characters = []
    pairings = []
    fandoms = []
    ratings = []
    relationships = []
    size_tags = []
    sizes = []
    statuses = []
    events = []
    genres = []
    warnings = []
    titles = []
    links = []
    summaries = []
    
    for soup in fanfic_soups:
        title_meta = soup.find('div', class_='FicTable_Title')
        titles.append(soup.find('a').text)
        links.append('fanfics.me' + soup.find('a')['href'])
        
        summaries.append(soup.find('td', class_='FicTbl_sammary').text)
        
        single = [char.text for char in soup.find_all(href=re.compile('/character.*'))]
        fic_pairings = [pair.text.split('/') for pair in soup.find_all(href=re.compile('/paring.*'))]
        for fic_pairing in fic_pairings:
            single += fic_pairing
        single = list(set(single))
        characters.append(', '.join(single))
            
        fic_pairings = [pair.text for pair in soup.find_all(href=re.compile('/paring.*'))]
        pairings.append(', '.join(fic_pairings))
        
        fic_fandoms = [fandom.text for fandom in soup.find_all(href=re.compile('/fandom.*'))]
        fandoms.append(', '.join(fic_fandoms))
        
        ratings.append(soup.find('span', class_='FicTable_Rating').text)
        relationships.append(soup.find('div', class_='FicTable_Title').find('h4').find('span').text.strip('()'))
    
        size_full = soup.find('span', class_='FicTable_Size').text.split('|')
        size_tags.append(size_full[0].strip())
        sizes.append(size_full[1].strip()[:-3])
    
        statuses.append(soup.find('span', class_='FicTable_Status').text.replace('\xa0', ' '))
        
        fic_events = [event.text for event in soup.find_all(href=re.compile('/find\?keyword=.*'))]
        events.append(', '.join(fic_events))

        meta_unfiltered = soup.find('td', class_='FicTbl_meta').text
        
        genres_match = re.search(genres_regex, meta)
        if match:
            genres.append(genres_match.group(1))
        else:
            genres.append('')
        
        warnings_match = re.search(warnings_regex, meta)
        if match:
            warnings.append(warnings_match.group(1))
        else:
            warnings.append('')
            
    data = {
        'title': titles,
        'summary': summaries,
        'characters': characters,
        'pairings': pairings,
        'fandoms': fandoms,
        'rating': ratings,
        'size_tag': size_tags,
        'size': sizes,
        'statuse': statuses,
        'events': events,
        'genres': genres,
        'warnings': warnings,
        'link': links
    }
    
    fanfictionDF = pd.DataFrame(data, columns = data.keys())
    return fanfictionDF

# %%
testDF = processPage('https://fanfics.me/find?fandom1=2&page=1')

# %%
testDF.to_csv('testDF.csv')

# %% [markdown]
# ## Теперь надо медленно, но верно проходить по каждой странице и добавлять в датафрейм результаты парсинга
